# %%
import pandas as pd

df0=pd.read_excel('Weather data.xlsx')
df0
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 1 2017-05-04   NaN        9.0   sunny
# 2 2017-05-05  28.0        NaN    snow
# 3 2017-05-06   NaN        7.0     NaN
# 4 2017-05-07  32.0        NaN    rain
# 5 2017-05-08   NaN        NaN   sunny
# 6 2017-05-09   NaN        NaN     NaN
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
type(df0.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import pandas as pd

df1=pd.read_excel('Weather data.xlsx', parse_dates=['day'])
df1
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 1 2017-05-04   NaN        9.0   sunny
# 2 2017-05-05  28.0        NaN    snow
# 3 2017-05-06   NaN        7.0     NaN
# 4 2017-05-07  32.0        NaN    rain
# 5 2017-05-08   NaN        NaN   sunny
# 6 2017-05-09   NaN        NaN     NaN
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
import pandas as pd

df1=pd.read_excel('Weather data.xlsx', parse_dates=['day'])
type(df1.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(df1.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df2= df1.fillna({
    'temp': 0,
    'windspeed':0,
    'event': 'no event'
})
df2
# Out:
#          day  temp  windspeed     event
# 0 2017-05-01  32.0        6.0      rain
# 1 2017-05-04   0.0        9.0     sunny
# 2 2017-05-05  28.0        0.0      snow
# 3 2017-05-06   0.0        7.0  no event
# 4 2017-05-07  32.0        0.0      rain
# 5 2017-05-08   0.0        0.0     sunny
# 6 2017-05-09   0.0        0.0  no event
# 7 2017-05-10  34.0        8.0    cloudy
# 8 2017-05-11  40.0       12.0     sunny

# %%
df2=df1.fillna(method='ffill')
df2
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 1 2017-05-04  32.0        9.0   sunny
# 2 2017-05-05  28.0        9.0    snow
# 3 2017-05-06  28.0        7.0    snow
# 4 2017-05-07  32.0        7.0    rain
# 5 2017-05-08  32.0        7.0   sunny
# 6 2017-05-09  32.0        7.0   sunny
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
 df2=df1.fillna(method='bfill')
df2
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 1 2017-05-04  28.0        9.0   sunny
# 2 2017-05-05  28.0        7.0    snow
# 3 2017-05-06  32.0        7.0    rain
# 4 2017-05-07  32.0        8.0    rain
# 5 2017-05-08  34.0        8.0   sunny
# 6 2017-05-09  34.0        8.0  cloudy
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
 df2=df1.fillna(method='bfill', axis='columns')
df2
# Out:
#          day   temp windspeed   event
# 0 2017-05-01   32.0       6.0    rain
# 1 2017-05-04    9.0       9.0   sunny
# 2 2017-05-05   28.0      snow    snow
# 3 2017-05-06    7.0       7.0     NaN
# 4 2017-05-07   32.0      rain    rain
# 5 2017-05-08  sunny     sunny   sunny
# 6 2017-05-09    NaT       NaT     NaT
# 7 2017-05-10   34.0       8.0  cloudy
# 8 2017-05-11   40.0      12.0   sunny

# %%
df2=df1.fillna(method='ffill', limit=1)
df2
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 1 2017-05-04  32.0        9.0   sunny
# 2 2017-05-05  28.0        9.0    snow
# 3 2017-05-06  28.0        7.0    snow
# 4 2017-05-07  32.0        7.0    rain
# 5 2017-05-08  32.0        NaN   sunny
# 6 2017-05-09   NaN        NaN   sunny
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
df2=df1.interpolate()
df2
# Out:
#          day       temp  windspeed   event
# 0 2017-05-01  32.000000       6.00    rain
# 1 2017-05-04  30.000000       9.00   sunny
# 2 2017-05-05  28.000000       8.00    snow
# 3 2017-05-06  30.000000       7.00     NaN
# 4 2017-05-07  32.000000       7.25    rain
# 5 2017-05-08  32.666667       7.50   sunny
# 6 2017-05-09  33.333333       7.75     NaN
# 7 2017-05-10  34.000000       8.00  cloudy
# 8 2017-05-11  40.000000      12.00   sunny

# %%
df2=df1.dropna()
df2
# Out:
#          day  temp  windspeed   event
# 0 2017-05-01  32.0        6.0    rain
# 7 2017-05-10  34.0        8.0  cloudy
# 8 2017-05-11  40.0       12.0   sunny

# %%
df2
# Out:
#             temp  windspeed   event
# day
# 2017-05-01  32.0        6.0    rain
# 2017-05-04   NaN        9.0   sunny
# 2017-05-05  28.0        NaN    snow
# 2017-05-06   NaN        7.0     NaN
# 2017-05-07  32.0        NaN    rain
# 2017-05-08   NaN        NaN   sunny
# 2017-05-09   NaN        NaN     NaN
# 2017-05-10  34.0        8.0  cloudy
# 2017-05-11  40.0       12.0   sunny

# %%
df3=df2.dropna(how='all')
df3
# Out:
#             temp  windspeed   event
# day
# 2017-05-01  32.0        6.0    rain
# 2017-05-04   NaN        9.0   sunny
# 2017-05-05  28.0        NaN    snow
# 2017-05-06   NaN        7.0     NaN
# 2017-05-07  32.0        NaN    rain
# 2017-05-08   NaN        NaN   sunny
# 2017-05-10  34.0        8.0  cloudy
# 2017-05-11  40.0       12.0   sunny

# %%
df3=df2.dropna(thresh=2)
df3
# Out:
#             temp  windspeed   event
# day
# 2017-05-01  32.0        6.0    rain
# 2017-05-04   NaN        9.0   sunny
# 2017-05-05  28.0        NaN    snow
# 2017-05-07  32.0        NaN    rain
# 2017-05-10  34.0        8.0  cloudy
# 2017-05-11  40.0       12.0   sunny

# %%
import pandas as pd
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = [0, 6]
ypoints = [0, 250]
plt.xlabel('x')
plt.ylabel('y')
plt.plot(xpoints, ypoints,'*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = [3, 8, 1, 10]
y2 = [6, 2, 7, 11]

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([3, 8, 1, 10])
b = np.array([6, 2, 7, 11])

plt.plot(a, b)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()
